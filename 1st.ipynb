# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mashlyn/online-retail-ii-uci")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 14.5M/14.5M [00:03<00:00, 4.73MB/s]
# Extracting files...
# Path to dataset files: /Users/sumansingh/.cache/kagglehub/datasets/mashlyn/online-retail-ii-uci/versions/3

# %%
import os
import pandas as pd

# `path` should be the result from the NEW Kaggle download
retail_file_path = os.path.join(path, "online_retail_II.csv")

print(retail_file_path)
print(os.path.exists(retail_file_path))

retail_df = pd.read_csv(retail_file_path)

print(retail_df.shape)
print(retail_df.columns.tolist())

retail_df.head()
# Out:
# /Users/sumansingh/.cache/kagglehub/datasets/mashlyn/online-retail-ii-uci/versions/3/online_retail_II.csv
# True
# (1067371, 8)
# ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country']
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# ...

# %%
retail_df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France

# %%
retail_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  str
#  1   StockCode    1067371 non-null  str
#  2   Description  1062989 non-null  str
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  str
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 65.1 MB

# %%
# Missing values in each column
print("\nMissing values per column:")
print(retail_df.isnull().sum())
# Out:
# Missing values per column:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
# Count cancelled invoices
cancelled_count = retail_df["Invoice"].astype(str).str.startswith("C").sum()
print("\nCancelled invoice rows:", cancelled_count)
