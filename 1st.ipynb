# %%
pip install plotly

# %%
pip install nbformat

# %%
pip install kagglehub

# %%
pip install pandas

# %%
import kagglehub
import os
import pandas as pd

dataset_path = kagglehub.dataset_download(
    "mnassrib/telecom-churn-datasets"
)

print("Dataset folder:", dataset_path)
print(os.listdir(dataset_path))

# %%
import glob

csv_files = glob.glob(os.path.join(dataset_path, "*.csv"))

print(csv_files)

file_path = csv_files[0]
df = pd.read_csv(file_path)

df.head()
# Out:
# ['/Users/sumansingh/.cache/kagglehub/datasets/mnassrib/telecom-churn-datasets/versions/1/churn-bigml-20.csv', '/Users/sumansingh/.cache/kagglehub/datasets/mnassrib/telecom-churn-datasets/versions/1/churn-bigml-80.csv']
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
# 2             56.59              317.8               97             27.01
# 3             18.77              137.3              102             11.67
# 4             20.28              215.1              109             18.28
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
# 2                160.6                128                7.23
# 3                189.6                105                8.53
# 4                178.7                 90                8.04
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# 1                12.7                 6               3.43
# 2                 5.4                 9               1.46
# 3                 7.7                 6               2.08
# 4                11.1                 1               3.00
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       4   True
# 2                       4   True
# 3                       2  False
# 4                       1  False
